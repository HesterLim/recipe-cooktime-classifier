# %%
# Load library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math 
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
# %matplotlib inline

# %% [markdown]
# ## Import Data

# %%
# Create URL
#test_csv = "~/COMP30027_2021_Project2_datasets/recipe_test.csv"
#train_csv = "~/COMP30027_2021_Project2_datasets/recipe_train.csv"

test_csv_2 = "C:\\Users\\kenne\\recipe-cooktime-predictor data\\COMP30027_2021_Project2_datasets\\recipe_test.csv"
train_csv_2 = "C:\\Users\\kenne\\recipe-cooktime-predictor data\\COMP30027_2021_Project2_datasets\\recipe_train.csv"

# Load Dataset 
test_df = pd.read_csv(test_csv_2)
train_df = pd.read_csv(train_csv_2)

#test_df = pd.read_csv(test_csv )
#train_df = pd.read_csv(train_csv)

# %%
import pickle
name = pickle.load(open("C:\\Users\\kenne\\recipe-cooktime-predictor data\\COMP30027_2021_Project2_datasets\\recipe_text_features_countvec\\train_name_countvectorizer.pkl", "rb"))
name_dict = name.vocabulary_

steps = pickle.load(open("C:\\Users\\kenne\\recipe-cooktime-predictor data\\COMP30027_2021_Project2_datasets\\recipe_text_features_countvec\\train_steps_countvectorizer.pkl", "rb"))
steps_dict = steps.vocabulary_

ingr = pickle.load(open("C:\\Users\\kenne\\recipe-cooktime-predictor data\\COMP30027_2021_Project2_datasets\\recipe_text_features_countvec\\train_ingr_countvectorizer.pkl", "rb"))
ingr_dict = ingr.vocabulary_
ingr_dict
# Out:
# {'margarine': 1584,
#  'olive': 1811,
#  'oil': 1806,
#  'celery': 499,
#  'onion': 1815,
#  'garlic': 1078,
#  'clove': 610,
#  'carrots': 475,
#  'low': 1539,
#  'sodium': 2442,
#  'chicken': 549,
#  'broth': 346,
#  'brown': 347,
#  'rice': 2188,
#  'pepper': 1935,
#  'salt': 2268,
#  'substitute': 2569,
#  'boneless': 285,
#  'skinless': 2405,
#  'breasts': 323,
#  'fresh': 1033,
#  'parsley': 1883,
#  'butter': 386,
#  'pinhead': 1994,
#  'oats': 1801,
#  'water': 2829,
#  'half': 1209,
#  'ground': 1186,
#  'beef': 197,
#  'green': 1175,
#  'tomato': 2690,
#  'sauce': 2289,
#  'chili': 557,
#  'powder': 2065,
#  'refrigerated': 2172,
#  'biscuits': 234,
#  'cheddar': 522,
#  'cheese': 526,
#  'sour': 2456,
#  'cream': 709,
#  'egg': 889,
#  'frozen': 1046,
#  'lemonade': 1481,
#  'catsup': 490,
#  'vinegar': 2806,
#  'sugar': 2574,
#  'cornstarch': 681,
#  'graham': 1145,
#  'cracker': 701,
#  'crumbs': 735,
#  'crunchy': 738,
#  'peanut': 1912,
#  'powdered': 2066,
#  'crisp': 721,
#  'cereal': 503,
#  'almond': 55,
#  'bark': 170,
#  'sourdough': 2457,
#  'bread': 311,
#  'eggs': 893,
#  'dried': 858,
#  'thyme': 2668,
#  'breakfast': 319,
#  'sausage': 2292,
#  'sharp': 2356,
#  'monterey': 1697,
#  'jack': 1328,
#  'milk': 1659,
#  'curry': 770,
#  'black': 246,
#  'orange': 1819,
#  'juice': 1365,
#  'mustard': 1732,
#  'unsweetened': 2774,
#  'raspberries': 2153,
#  'yolks': 2891,
#  'grand': 1152,
#  'marnier': 1595,
#  'vanilla': 2779,
#  'white': 2852,
#  'semisweet': 2338,
#  'chocolate': 571,
#  'whipping': 2849,
#  'seedless': 2330,
#  'raspberry': 2154,
#  'jam': 1334,
#  'campbell': 427,
#  'healthy': 1238,
#  'request': 2178,
#  'broccoli': 338,
#  'soup': 2455,
#  'nonfat': 1774,
#  'fat': 944,
#  'kraft': 1435,
#  'favorites': 947,
#  'free': 1028,
#  'potatoes': 2060,
#  'corn': 673,
#  'flakes': 988,
#  'dijon': 827,
#  'lime': 1498,
#  'skirt': 2408,
#  'steaks': 2523,
#  'lemon': 1480,
#  'capers': 448,
#  'cayenne': 496,
#  'leaves': 1471,
#  'fettuccine': 955,
#  'sea': 2317,
#  'bass': 181,
#  'vegetable': 2787,
#  'red': 2165,
#  'coriander': 671,
#  'flat': 992,
#  'leaf': 1467,
#  'salmon': 2266,
#  'fillets': 969,
#  'cranberry': 705,
#  'jelly': 1351,
#  'chilies': 559,
#  'fish': 983,
#  'lettuce': 1486,
#  'lean': 1469,
#  'chives': 569,
#  'basil': 178,
#  'oregano': 1824,
#  'blue': 266,
#  'deli': 802,
#  'turkey': 2741,
#  'stove': 2547,
#  'stuffing': 2565,
#  'mix': 1682,
#  'gravy': 1170,
#  'gammon': 1072,
#  'stock': 2540,
#  'marjoram': 1591,
#  'dill': 829,
#  'kosher': 1434,
#  'unsalted': 2769,
#  'pecans': 1921,
#  'yellow': 2885,
#  'cake': 411,
#  'instant': 1319,
#  'pudding': 2099,
#  'irish': 1321,
#  'long': 1534,
#  'grain': 1147,
#  'kernels': 1397,
#  'mozzarella': 1714,
#  'pine': 1992,
#  'nuts': 1795,
#  'spinach': 2487,
#  'wine': 2859,
#  'light': 1492,
#  'winter': 2862,
#  'squash': 2508,
#  'maple': 1579,
#  'syrup': 2603,
#  'soy': 2462,
#  'ginger': 1107,
#  'sage': 2260,
#  'macadamia': 1551,
#  'cashews': 479,
#  'dates': 790,
#  'coconut': 625,
#  'agave': 33,
#  'nectar': 1749,
#  'bean': 187,
#  'mixed': 1683,
#  'berries': 218,
#  'flour': 1004,
#  'baking': 153,
#  'cinnamon': 593,
#  'unbleached': 2762,
#  'cane': 433,
#  'zest': 2898,
#  'balsamic': 159,
#  'extra': 925,
#  'virgin': 2808,
#  'raw': 2158,
#  'fennel': 950,
#  'bulb': 366,
#  'boston': 291,
#  'diced': 824,
#  'tomatoes': 2692,
#  'condensed': 655,
#  'pretzels': 2082,
#  'plain': 2010,
#  'candy': 432,
#  'hershey': 1259,
#  'hugs': 1297,
#  'chocolates': 572,
#  'kisses': 1417,
#  'wheat': 2842,
#  'cottage': 686,
#  'splenda': 2490,
#  'onions': 1816,
#  'cloves': 612,
#  'sherry': 2365,
#  'yukon': 2894,
#  'gold': 1130,
#  'potato': 2059,
#  'rosemary': 2233,
#  'heavy': 1243,
#  'freshly': 1034,
#  'purpose': 2112,
#  'soda': 2441,
#  'shortening': 2380,
#  'buttermilk': 396,
#  'bananas': 162,
#  'banana': 161,
#  'granulated': 1157,
#  'goat': 1126,
#  'roasting': 2211,
#  'chickens': 550,
#  'bacon': 139,
#  'peas': 1917,
#  'cauliflower': 491,
#  'cabbage': 401,
#  'carrot': 474,
#  'mayonnaise': 1622,
#  'olives': 1812,
#  'garbanzo': 1075,
#  'beans': 188,
#  'sun': 2580,
#  'bell': 208,
#  'peppers': 1942,
#  'cumin': 756,
#  'breast': 322,
#  'halves': 1214,
#  'mint': 1670,
#  'sprig': 2497,
#  'smoked': 2425,
#  'italian': 1326,
#  'seasoning': 2321,
#  'cannellini': 436,
#  'nutmeg': 1791,
#  'shell': 2361,
#  'pasta': 1894,
#  'parmesan': 1880,
#  'acorn': 24,
#  'turmeric': 2743,
#  'pork': 2048,
#  'chops': 578,
#  'apple': 96,
#  'cider': 591,
#  'noodles': 1778,
#  'cornmeal': 680,
#  'creamed': 710,
#  'zucchini': 2904,
#  'quick': 2120,
#  'new': 1759,
#  'asparagus': 120,
#  'spears': 2478,
#  'cherry': 536,
#  'yeast': 2884,
#  'sweetened': 2596,
#  'flaked': 987,
#  'extract': 926,
#  'dark': 785,
#  'cooking': 666,
#  'spray': 2494,
#  'semi': 2337,
#  'sweet': 2594,
#  'chips': 567,
#  'applesauce': 99,
#  'whites': 2853,
#  'mashed': 1608,
#  'roma': 2221,
#  'spaetzle': 2467,
#  'concentrate': 649,
#  'mushroom': 1728,
#  'pie': 1974,
#  'spice': 2482,
#  'sticks': 2535,
#  'cocoa': 624,
#  'spaghetti': 2468,
#  'sliced': 2413,
#  'mushrooms': 1729,
#  'creamy': 712,
#  'dressing': 857,
#  'chopped': 577,
#  'romano': 2224,
#  'yam': 2881,
#  'scallion': 2300,
#  'pumpkin': 2105,
#  'puree': 2109,
#  'skim': 2403,
#  'bouillon': 296,
#  'hamburger': 1216,
#  'meat': 1628,
#  'taco': 2611,
#  'macaroni': 1552,
#  'salsa': 2267,
#  'velveeta': 2791,
#  'dr': 852,
#  'cola': 633,
#  'ketchup': 1398,
#  'minced': 1664,
#  'crushed': 739,
#  'icing': 1309,
#  'yogurt': 2889,
#  'ice': 1306,
#  'cube': 748,
#  'pears': 1916,
#  'unbaked': 2760,
#  'colored': 641,
#  'sprinkles': 2501,
#  'apples': 98,
#  'food': 1014,
#  'coloring': 642,
#  'bay': 186,
#  'peppercorns': 1937,
#  'mace': 1554,
#  'sesame': 2343,
#  'seeds': 2331,
#  'bulgur': 369,
#  'cold': 636,
#  'fruit': 1048,
#  'sunflower': 2583,
#  'pimentos': 1988,
#  'pickle': 1969,
#  'horseradish': 1289,
#  'honey': 1283,
#  'chuck': 585,
#  'country': 690,
#  'ham': 1215,
#  'buns': 376,
#  'rind': 2195,
#  'lemons': 1483,
#  'swordfish': 2602,
#  'steak': 2521,
#  'old': 1809,
#  'fashioned': 942,
#  'pitted': 2006,
#  'walnuts': 2824,
#  'raisins': 2143,
#  'self': 2335,
#  'rising': 2203,
#  'canned': 435,
#  'jalapeno': 1332,
#  'venison': 2792,
#  'loin': 1530,
#  'confectioners': 659,
#  'lavender': 1462,
#  'caramels': 460,
#  'dry': 864,
#  'roasted': 2210,
#  'peanuts': 1913,
#  'reduced': 2168,
#  'poppy': 2045,
#  'coffee': 628,
#  'granules': 1159,
#  'hot': 1291,
#  'brandy': 306,
#  'malt': 1567,
#  'vidalia': 2801,
#  'cucumber': 751,
#  'vinaigrette': 2804,
#  'pesto': 1955,
#  'balls': 157,
#  'salad': 2263,
#  'paste': 1895,
#  'bourbon': 298,
#  'breadcrumbs': 313,
#  'ranch': 2147,
#  'quail': 2114,
#  'paprika': 1873,
#  'wedge': 2835,
#  'avocado': 129,
#  'florets': 1002,
#  'roast': 2209,
#  'cooked': 663,
#  'mexican': 1650,
#  'style': 2567,
#  'miniature': 1669,
#  'party': 1889,
#  'rye': 2255,
#  'rounds': 2241,
#  'lump': 1543,
#  'crabmeat': 698,
#  'cilantro': 592,
#  'strawberries': 2552,
#  'mcintosh': 1626,
#  'rolled': 2218,
#  'almonds': 56,
#  'marsala': 1598,
#  'picante': 1966,
#  'tortillas': 2708,
#  'maraschino': 1580,
#  'cherries': 535,
#  'ribs': 2187,
#  'oatmeal': 1799,
#  'molasses': 1690,
#  'candied': 429,
#  'allspice': 54,
#  'andouille': 80,
#  'beer': 200,
#  'stem': 2527,
#  'seed': 2329,
#  'asiago': 118,
#  'artichoke': 111,
#  'heart': 1239,
#  'shallot': 2347,
#  'gouda': 1140,
#  'hash': 1230,
#  'browns': 352,
#  'strawberry': 2553,
#  'firm': 982,
#  'tofu': 2684,
#  'ricotta': 2190,
#  'jumbo': 1368,
#  'shrimp': 2385,
#  'unseasoned': 2770,
#  'chow': 581,
#  'mein': 1636,
#  'prepared': 2077,
#  'pizza': 2007,
#  'crust': 740,
#  'hearts': 1240,
#  'bulbs': 367,
#  'peppercorn': 1936,
#  'liquid': 1514,
#  'pectin': 1923,
#  'vegetarian': 2789,
#  'kidney': 1403,
#  'slivered': 2415,
#  'brie': 329,
#  'round': 2240,
#  'marmalade': 1593,
#  'baguette': 145,
#  'sirloin': 2397,
#  'bran': 304,
#  'currant': 768,
#  'golden': 1131,
#  'raisin': 2141,
#  'gelatin': 1085,
#  'boiling': 278,
#  'neufchatel': 1758,
#  'cool': 667,
#  'whip': 2847,
#  'lite': 1517,
#  'filling': 970,
#  'solid': 2446,
#  'nonstick': 1776,
#  'flounder': 1003,
#  'desiccated': 812,
#  'table': 2607,
#  'rum': 2247,
#  'vodka': 2811,
#  'worchestershire': 2871,
#  'spanish': 2471,
#  'russet': 2251,
#  'snickers': 2437,
#  'bars': 173,
#  'cookie': 664,
#  'brewed': 326,
#  'caramel': 458,
#  'cubes': 750,
#  'whipped': 2848,
#  'silken': 2391,
#  'okra': 1808,
#  'cajun': 410,
#  'great': 1173,
#  'northern': 1782,
#  'pinto': 1997,
#  'dehydrated': 800,
#  'vegetables': 2788,
#  'fusilli': 1062,
#  'bone': 284,
#  'lamb': 1449,
#  'stew': 2530,
#  'mangoes': 1573,
#  'butterscotch': 398,
#  'barley': 171,
#  'garam': 1074,
#  'masala': 1606,
#  'yoghurt': 2888,
#  'mango': 1572,
#  'chutney': 589,
#  'merlot': 1645,
#  'racks': 2131,
#  'peaches': 1910,
#  'poultry': 2061,
#  'caraway': 461,
#  'cardamom': 465,
#  'pods': 2026,
#  'feta': 954,
#  'phyllo': 1965,
#  'pastry': 1899,
#  'sheets': 2360,
#  'greens': 1176,
#  'cashew': 478,
#  'bittersweet': 244,
#  'soya': 2463,
#  'coarse': 615,
#  'gruyere': 1189,
#  'plum': 2017,
#  'camembert': 422,
#  'leave': 1470,
#  'shallots': 2348,
#  'canola': 440,
#  'chipotle': 565,
#  'chiles': 556,
#  'adobo': 28,
#  'limeade': 1499,
#  'tequila': 2653,
#  'triple': 2723,
#  'sec': 2325,
#  'soft': 2444,
#  'stale': 2513,
#  'crumb': 733,
#  'cracked': 700,
#  'french': 1030,
#  'baguettes': 146,
#  'natural': 1742,
#  'soymilk': 2466,
#  'celeriac': 498,
#  'stilton': 2537,
#  'single': 2396,
#  'whey': 2846,
#  'bisquick': 236,
#  'gnocchi': 1125,
#  'flavored': 994,
#  'ramen': 2145,
#  'tuna': 2738,
#  'worcestershire': 2870,
#  'salted': 2269,
#  'pretzel': 2081,
#  'stick': 2533,
#  'chex': 545,
#  'nips': 1767,
#  'nacho': 1737,
#  'tortilla': 2707,
#  'popcorn': 2043,
#  'panko': 1867,
#  'serrano': 2340,
#  'thai': 2659,
#  'chile': 555,
#  'yolk': 2890,
#  'flavor': 993,
#  'swiss': 2600,
#  'warm': 2825,
#  'partridges': 1887,
#  'grapes': 1163,
#  'mirin': 1675,
#  'cookies': 665,
#  'herb': 1252,
#  'penne': 1929,
#  'link': 1510,
#  'meatless': 1630,
#  'pineapple': 1993,
#  'parmigiano': 1881,
#  'reggiano': 2173,
#  'tasty': 2636,
#  'gluten': 1122,
#  'guar': 1193,
#  'gum': 1197,
#  'thighs': 2662,
#  'chunk': 586,
#  'tomatillos': 2689,
#  'mild': 1658,
#  'rhubarb': 2184,
#  'tabasco': 2606,
#  'weed': 2837,
#  'lawry': 1463,
#  'seasoned': 2320,
#  'fried': 1036,
#  'amish': 71,
#  'starter': 2519,
#  'small': 2418,
#  'mexicorn': 1652,
#  'kernel': 1396,
#  'apricot': 100,
#  'evaporated': 923,
#  'miracle': 1673,
#  'rotini': 2237,
#  'relish': 2175,
#  'orzo': 1833,
#  'chickpeas': 552,
#  'baby': 134,
#  'greek': 1174,
#  'dough': 848,
#  'pepperoni': 1941,
#  'slices': 2414,
#  'marinara': 1589,
#  'topping': 2701,
#  'romaine': 2222,
#  'tenderloins': 2649,
#  'roughy': 2239,
#  'kalamata': 1376,
#  'sauvignon': 2296,
#  'blanc': 254,
#  'frosting': 1045,
#  'peel': 1924,
#  'wild': 2858,
#  'vermicelli': 2796,
#  'double': 847,
#  'acting': 25,
#  'pure': 2108,
#  'currants': 769,
#  'marshmallows': 1600,
#  'wafer': 2813,
#  'chick': 548,
#  'pea': 1908,
#  'bottoms': 293,
#  'scallions': 2301,
#  'sheet': 2359,
#  'delicious': 805,
#  'mini': 1668,
#  'preserves': 2079,
#  'strong': 2562,
#  'eggplant': 891,
#  'peppermint': 1939,
#  'patties': 1903,
#  'fingerling': 978,
#  'caster': 485,
#  'portabella': 2051,
#  'stems': 2528,
#  'pieces': 1976,
#  'hard': 1221,
#  'boiled': 277,
#  'lentils': 1485,
#  'english': 909,
#  'muffins': 1720,
#  'shells': 2363,
#  'brand': 305,
#  'rotel': 2235,
#  'breadcrumb': 312,
#  'herbal': 1253,
#  'tea': 2639,
#  'bags': 144,
#  'couscous': 694,
#  'inch': 1313,
#  'tart': 2632,
#  'limes': 1500,
#  'tenderloin': 2648,
#  'madras': 1559,
#  'hungarian': 1299,
#  'whiskey': 2850,
#  'pawpaw': 1907,
#  'original': 1830,
#  'heinz': 1244,
#  '57': 9,
#  'snow': 2438,
#  'prawns': 2069,
#  'papaya': 1868,
#  'blueberries': 267,
#  'mandarin': 1570,
#  'oranges': 1821,
#  'tidbits': 2671,
#  'veal': 2783,
#  'shoulder': 2381,
#  'protein': 2092,
#  'beet': 201,
#  'roquefort': 2231,
#  'delicata': 803,
#  'cranberries': 704,
#  'pulp': 2103,
#  'doughnut': 849,
#  'holes': 1274,
#  'toffee': 2683,
#  'lowfat': 1540,
#  'legs': 1479,
#  'snapper': 2435,
#  'creole': 716,
#  'saltine': 2270,
#  'crackers': 702,
#  'shredded': 2383,
#  'tangerine': 2623,
#  'head': 1236,
#  'bits': 241,
#  'shiitake': 2367,
#  'cremini': 715,
#  'prosciutto': 2090,
#  'packed': 1847,
#  'mrs': 1715,
#  'grass': 1166,
#  'homestyle': 1280,
#  'recipe': 2164,
#  'boil': 276,
#  'lasagna': 1457,
#  'coleslaw': 638,
#  'asian': 119,
#  'active': 26,
#  'pimento': 1987,
#  'stuffed': 2564,
#  'radishes': 2136,
#  'gingerroot': 1110,
#  'large': 1456,
#  'clams': 599,
#  'chinese': 562,
#  'duck': 865,
#  'provolone': 2095,
#  'sprouts': 2504,
#  'stone': 2544,
#  'caps': 452,
#  'wafers': 2814,
#  'blueberry': 268,
#  'refried': 2171,
#  'iceberg': 1307,
#  'leeks': 1477,
#  'button': 400,
#  'lobsters': 1528,
#  'fillet': 968,
#  'berry': 219,
#  'unflavored': 2765,
#  'jell': 1348,
#  'medium': 1635,
#  'habaneros': 1203,
#  'capsicums': 454,
#  'basmati': 180,
#  'star': 2515,
#  'anise': 88,
#  'blend': 258,
#  'rolls': 2219,
#  'eggplants': 892,
#  'drumsticks': 863,
#  'simply': 2395,
#  'stewed': 2531,
#  'cognac': 629,
#  '35': 7,
#  'basa': 175,
#  'ale': 48,
#  'spread': 2495,
#  'rib': 2185,
#  'eye': 927,
#  'bagels': 143,
#  'american': 69,
#  'noodle': 1777,
#  'chunky': 588,
#  'pimiento': 1989,
#  'wooden': 2869,
#  'avocados': 131,
#  'catalina': 487,
#  'nutritional': 1794,
#  'flax': 996,
#  'miso': 1677,
#  'parsnip': 1884,
#  'elbow': 895,
#  'breadfruit': 315,
#  'buffalo': 364,
#  'jellied': 1349,
#  'plantains': 2014,
#  'turnips': 2745,
#  'fine': 973,
#  'flowers': 1007,
#  'peach': 1909,
#  'chunks': 587,
#  'short': 2376,
#  'lipton': 1512,
#  'grape': 1160,
#  'blackberries': 248,
#  'crusts': 741,
#  'alfredo': 51,
#  'simple': 2394,
#  'cutlets': 774,
#  'pancetta': 1861,
#  'ritz': 2206,
#  'ball': 155,
#  'oreo': 1825,
#  'stir': 2539,
#  'fry': 1052,
#  'boboli': 271,
#  'toppings': 2702,
#  'pre': 2070,
#  'pillsbury': 1985,
#  'crescent': 718,
#  'dinner': 831,
#  'ripe': 2200,
#  'toasted': 2680,
#  'crab': 697,
#  'hardboiled': 1222,
#  'barbecue': 166,
#  'puff': 2100,
#  'pistachios': 2003,
#  'split': 2491,
#  'cut': 772,
#  'texas': 2657,
#  'toast': 2679,
#  'hoisin': 1271,
#  'enchilada': 903,
#  'lard': 1454,
#  'bulk': 370,
#  'cutlet': 773,
#  'hunts': 1301,
#  'sifted': 2390,
#  'hokkien': 1273,
#  'artichokes': 112,
#  'tarragon': 2631,
#  'tenders': 2650,
#  'wedges': 2836,
#  'haddock': 1205,
#  'pickled': 1970,
#  'leek': 1476,
#  'hickory': 1262,
#  'smoke': 2424,
#  'minestrone': 1667,
#  'beaters': 191,
#  'germ': 1094,
#  'meal': 1627,
#  'krispies': 1437,
#  'rose': 2232,
#  'soba': 2440,
#  'bow': 300,
#  'tie': 2672,
#  'parsnips': 1885,
#  'uncle': 2763,
#  'bens': 215,
#  'ready': 2159,
#  'braggs': 303,
#  'aminos': 70,
#  'rutabaga': 2253,
#  'flakey': 989,
#  'dogs': 842,
#  'watermelon': 2831,
#  'kiwi': 1421,
#  'fruits': 1050,
#  'cheez': 533,
#  'capsicum': 453,
#  'ketjap': 1399,
#  'manis': 1576,
#  'brisket': 334,
#  'pickling': 1972,
#  'spices': 2484,
#  'anaheim': 74,
#  'pearl': 1915,
#  'hominy': 1281,
#  'verde': 2795,
#  'ancho': 76,
#  'curls': 766,
#  'polish': 2031,
#  'cakes': 412,
#  'brine': 331,
#  'harissa': 1226,
#  'sprigs': 2498,
#  'bosc': 290,
#  'chard': 516,
#  'angel': 82,
#  'hair': 1206,
#  'bicarbonate': 227,
#  'raising': 2142,
#  'lily': 1495,
#  'processed': 2087,
#  'schnapps': 2308,
#  'creme': 714,
#  'cacao': 403,
#  'canes': 434,
#  'aluminum': 61,
#  'foil': 1010,
#  'tamarind': 2620,
#  'granular': 1156,
#  'blackberry': 249,
#  'tri': 2721,
#  'color': 640,
#  'spiral': 2488,
#  'stewing': 2532,
#  'lentil': 1484,
#  'liqueur': 1513,
#  'thickened': 2660,
#  'wonton': 2867,
#  'wrapper': 2875,
#  'segments': 2332,
#  'summer': 2579,
#  'pancake': 1859,
#  'nestle': 1756,
#  'swirled': 2599,
#  'morsels': 1707,
#  'scallops': 2305,
#  'converted': 662,
#  'consomme': 660,
#  'fig': 961,
#  'preserved': 2078,
#  'manchego': 1569,
#  'tartar': 2633,
#  'marshmallow': 1599,
#  'albacore': 45,
#  'pickles': 1971,
#  'prune': 2096,
#  'rootbeer': 2229,
#  'float': 1000,
#  'root': 2228,
#  'decorator': 797,
#  'herbs': 1257,
#  'fraiche': 1020,
#  'rusks': 2250,
#  'flavoring': 995,
#  'pandan': 1863,
#  'filled': 967,
#  'sandwich': 2278,
#  'lollipop': 1531,
#  'cod': 627,
#  'clam': 597,
#  'curd': 762,
#  'watercress': 2830,
#  'walnut': 2823,
#  'farfalle': 933,
#  'banane': 163,
#  'galliano': 1069,
#  'methi': 1648,
#  'meringue': 1643,
#  'frank': 1024,
#  'anchovies': 77,
#  'blackberrie': 247,
#  'hass': 1231,
#  'avocadoes': 130,
#  'essence': 919,
#  'creamer': 711,
#  'wings': 2861,
#  'rings': 2199,
#  'hoagie': 1268,
#  'brussels': 355,
#  'sprout': 2503,
#  'arugula': 115,
#  'floury': 1005,
#  'rock': 2214,
#  'umeboshi': 2758,
#  'nori': 1781,
#  'quinoa': 2125,
#  'granule': 1158,
#  'emmenthaler': 901,
#  'pumpernickel': 2104,
#  'buds': 362,
#  'demerara': 810,
#  'squid': 2510,
#  'palm': 1853,
#  'kaffir': 1373,
#  'gram': 1149,
#  'mostaccioli': 1710,
#  'brownie': 349,
#  'cups': 760,
#  'belgian': 206,
#  'endive': 904,
#  'idaho': 1310,
#  'smooth': 2428,
#  'oat': 1797,
#  'cantaloupe': 441,
#  'croissant': 727,
#  'sake': 2262,
#  'scallop': 2302,
#  'pistachio': 2002,
#  'nut': 1788,
#  'kumquat': 1439,
#  'real': 2160,
#  'bamboo': 160,
#  'shoots': 2375,
#  'buckwheat': 359,
#  'butternut': 397,
#  'tortellini': 2705,
#  'weetabix': 2839,
#  'shank': 2350,
#  'oxtails': 1840,
#  'filet': 965,
#  'rabbit': 2127,
#  'jeera': 1346,
#  'tenderizer': 2647,
#  'linguine': 1509,
#  'frangelico': 1023,
#  'amaretto': 64,
#  'popsicle': 2046,
#  'decorative': 796,
#  'candies': 430,
#  'dog': 841,
#  'bun': 374,
#  'pod': 2025,
#  'cured': 764,
#  'paper': 1870,
#  'mung': 1726,
#  'imitation': 1311,
#  'kim': 1407,
#  'chee': 523,
#  'striped': 2559,
#  'hazelnuts': 1235,
#  'tawny': 2638,
#  'port': 2050,
#  'chorizo': 579,
#  'lima': 1496,
#  'matzo': 1614,
#  'sazon': 2299,
#  'goya': 1143,
#  'azafran': 132,
#  'pita': 2005,
#  'breads': 316,
#  'broccolini': 339,
#  'pomegranate': 2037,
#  'curacao': 761,
#  'gin': 1105,
#  'grapefruit': 1161,
#  'calf': 416,
#  'liver': 1522,
#  'kielbasa': 1405,
#  'chestnuts': 541,
#  'passion': 1893,
#  'organic': 1826,
#  'spring': 2499,
#  'cantaloupes': 442,
#  'parma': 1879,
#  'little': 1519,
#  'smokies': 2427,
#  'sausages': 2293,
#  ...}

# %%
import scipy
scipy.sparse.load_npz('C:\\Users\\kenne\\recipe-cooktime-predictor data\\COMP30027_2021_Project2_datasets\\recipe_text_features_countvec\\train_name_vec.npz')
# Out:
# <40000x10892 sparse matrix of type '<class 'numpy.int64'>'
# 	with 152716 stored elements in Compressed Sparse Row format>

# %%
pd.read_csv(r"C:\\Users\\kenne\\recipe-cooktime-predictor data\\COMP30027_2021_Project2_datasets\\recipe_text_features_doc2vec50\\recipe_text_features_doc2vec50\\train_name_doc2vec50.csv", index_col = False, delimiter = ',', header=None)
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.040233  0.076782  0.249360 -0.181925  0.248722 -0.588148  0.535760
# 1     -0.171015  0.076204  0.016986 -0.208875 -0.241924 -0.235768  0.214952
# 2     -0.004516  0.002639  0.045212  0.064354 -0.295956 -0.030037 -0.125290
# 3      0.398416 -0.289314  0.120874 -0.109078  0.172739 -0.329223 -0.174549
# 4     -0.024000  0.188942 -0.060302  0.114219 -0.021253  0.168473 -0.003027
# ...         ...       ...       ...       ...       ...       ...       ...
# 39995  0.215868  0.233168 -0.006542 -0.326691 -0.154234  0.046174  0.119195
# 39996 -0.094745  0.129695  0.064144 -0.113078 -0.185521 -0.018393  0.161694
# 39997 -0.306564  0.022663 -0.074049  0.026526 -0.115985 -0.108808 -0.028160
# 39998  0.103624  0.226626 -0.132034 -0.124793  0.229029 -0.065741  0.069570
# 39999 -0.030284  0.218631 -0.038716  0.104782  0.187953 -0.575098  0.117146
#
#              7         8         9   ...        40        41        42  \
# 0     -0.060977 -0.376367  0.119354  ... -0.213119 -0.106274 -0.123403
# 1     -0.229491 -0.083370  0.026395  ... -0.011173  0.040074 -0.027705
# 2      0.060692 -0.252764 -0.117760  ... -0.061929  0.035654  0.170956
# 3      0.240794 -0.020434 -0.149348  ... -0.100928  0.184699  0.077573
# 4      0.020890 -0.256069  0.276312  ... -0.193937  0.100599 -0.018302
# ...         ...       ...       ...  ...       ...       ...       ...
# 39995 -0.040960  0.271929  0.129032  ...  0.053267  0.019821 -0.057230
# 39996  0.130748 -0.224510  0.123720  ...  0.012002 -0.124835  0.023486
# 39997  0.134257 -0.169984 -0.043473  ...  0.102775 -0.109357 -0.047005
# 39998  0.210206  0.003720  0.013455  ...  0.045544 -0.412534  0.174328
# 39999  0.328395 -0.154484  0.525169  ...  0.132577 -0.339183  0.396991
#
#              43        44        45        46        47        48        49
# 0      0.046686 -0.013966 -0.225444  0.175705  0.456324 -0.195779 -0.179950
# 1      0.128443 -0.185171  0.040576  0.061800  0.078797  0.089783 -0.066999
# 2      0.169887  0.141687 -0.141490 -0.088364  0.013859  0.056343  0.015666
# 3      0.001083  0.299368 -0.118474 -0.114365  0.019365  0.065447  0.093216
# 4      0.002130  0.135032  0.093407 -0.068625 -0.007603  0.272904 -0.372245
# ...         ...       ...       ...       ...       ...       ...       ...
# 39995  0.252097  0.044637  0.228430 -0.132554 -0.320755  0.145350 -0.130995
# 39996 -0.069524 -0.105185 -0.029991  0.008550  0.012549  0.062497  0.008072
# 39997  0.201690  0.065266 -0.332215  0.002661 -0.268172  0.286195 -0.146461
# 39998  0.414477  0.296386  0.092027  0.258256 -0.092929 -0.024084 -0.284711
# 39999 -0.074579 -0.015658  0.346640 -0.413532  0.148193  0.242176 -0.169899
#
# [40000 rows x 50 columns]

# %%
X = train_df[['n_steps', 'n_ingredients']]
y = train_df['duration_label']

# %% [markdown]
# ## Data Modelling

# %%
one_r = DecisionTreeClassifier(max_depth=1)
one_r.fit(X, y)
dt = DecisionTreeClassifier(max_depth=None)
dt.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
one_r_acc = one_r.score(X,y)
dt_acc = dt.score(X,y)
print("1-R accuracy: {}; DT accuracy: {}".format(one_r_acc, dt_acc))
# Out:
# 1-R accuracy: 0.62165; DT accuracy: 0.644125

# %%
test_id = test_df.index
data = {'id': test_id+1, 'duration_label': ybar}
df = pd.DataFrame(data)
df.to_csv('predict.csv', index=False)

# %%
C = 1.0
linear_svc = svm.SVC(kernel='linear', C=C)

#linear_svc.fit(X,y)

#linear_svc_acc = linear_svc.score(X,y)
#print("Linear SVC accuracy: {}".format(linear_svc_acc))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score


#try to change C to 1000 or 0.001
C = 1.0  # SVM regularization parameter

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X, y)
knn_acc = knn.score(X,y)
print("kNN accuracy: {}".format(knn_acc))
# Out:
# kNN accuracy: 0.598675

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X,y)
log_reg_acc = log_reg.score(X,y)
print("Logistic Regression accuracy: {}".format(log_reg_acc))
# Out:
# Logistic Regression accuracy: 0.637025

# %% [markdown]
# ## Model Selection

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB
models = [GaussianNB(),
          MultinomialNB(),
          DecisionTreeClassifier(),
          KNeighborsClassifier(),
          LogisticRegression()]
titles = ['GNB',
          'MNB',
          'Decision Tree',
          'KNN',
          'Logistic Regression']

for title, model in zip(titles, models):
    model.fit(X,y)
    acc = model.score(X,y)
    print(title, "Accuracy:",acc)
# Out:
# GNB Accuracy: 0.619575
# MNB Accuracy: 0.523575
# Decision Tree Accuracy: 0.644125
# KNN Accuracy: 0.598675
# Logistic Regression Accuracy: 0.637025

# %%
from sklearn.model_selection import cross_val_score

models = [GaussianNB(),
          MultinomialNB(),
          DecisionTreeClassifier(),
          KNeighborsClassifier(),
          LogisticRegression()]

for title, model in zip(titles, models):
    acc = np.mean(cross_val_score(model, X, y, cv=10))
    
    print(title, "Accuracy:",acc)
# Out:
# GNB Accuracy: 0.6193
# MNB Accuracy: 0.523475
# Decision Tree Accuracy: 0.6340250000000001
# KNN Accuracy: 0.590725
# Logistic Regression Accuracy: 0.637

# %% [markdown]
# ## Model Testing

# %%
from sklearn.model_selection import cross_validate

log = LogisticRegression()
log.fit(X, y)
# Out:
# LogisticRegression()

# %%
X_test = test_df[['n_steps', 'n_ingredients']]
ybar = log.predict(X_test)

test_id = test_df.index
data = {'id': test_id+1, 'duration_label': ybar}
df = pd.DataFrame(data)
df.to_csv('predict.csv', index=False)
